# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8n.pt")

# %%
model
# Out:
# YOLO(
#   (model): DetectionModel(
#     (model): Sequential(
#       (0): Conv(
#         (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (1): Conv(
#         (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(48, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %%
import cv2
from cv2 import VideoCapture

# %%
cap = VideoCapture('test2.mp4')

# %%
door_line_y = 300  # Y-coordinate of the door threshold line
offset = 30        # Pixel offset to avoid double counting

# Counters
enter_count = 0
exit_count = 0

# Trackers memory
track_memory = {}

# %%
ret, frame = cap.read()

# %%
frame.shape
# Out:
# (568, 320, 3)

# %%
DOOR_ROI = (85, 45, 220, 290)

# %%
x1_door, y1_door, x2_door, y2_door = DOOR_ROI

# %%
cv2.rectangle(frame, (x1_door, y1_door), (x2_door, y2_door), (0, 255, 0), 2)
cv2.putText(frame, "DOOR ROI", (x1_door, y1_door - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
# Out:
# array([[[206, 208, 210],
#         [203, 205, 207],
#         [201, 203, 205],
#         ...,
#         [ 65,  75,  87],
#         [ 94, 104, 116],
#         [102, 112, 124]],
#
#        [[206, 208, 210],
#         [203, 205, 207],
#         [201, 203, 205],
#         ...,
#         [ 65,  75,  87],
#         [ 94, 104, 116],
#         [102, 112, 124]],
#
#        [[206, 208, 210],
#         [203, 205, 207],
#         [201, 203, 205],
#         ...,
#         [ 65,  75,  87],
#         [ 95, 105, 117],
#         [103, 113, 125]],
#
#        ...,
#
#        [[123, 133, 143],
#         [112, 122, 132],
#         [118, 128, 138],
#         ...,
#         [112, 119, 130],
#         [112, 119, 130],
#         [113, 120, 131]],
#
#        [[116, 126, 136],
#         [116, 126, 136],
#         [125, 135, 145],
#         ...,
#         [112, 119, 130],
#         [113, 120, 131],
#         [113, 120, 131]],
#
#        [[113, 123, 133],
#         [117, 127, 137],
#         [129, 139, 149],
# ...

# %%
cv2.imshow('Frame Viewer', frame)

    # 2. Wait for a key press (0 means wait indefinitely)
    # This is essential for the window to remain open until you close it.
cv2.waitKey(0)
    
    # 3. Destroy all the OpenCV windows once a key is pressed
cv2.destroyAllWindows()
